# %%
from pyshacl import validate

f = open('shacl.ttl')
shapes_file = f.read()
shapes_file_format = 'turtle'

data_file = '''{"@type":"bio:DataCatalog"}'''
data_file_format = 'json-ld'

# %%
conforms, v_graph, v_text = validate(data_file, shacl_graph=shapes_file,
                                     data_graph_format=data_file_format,
                                     shacl_graph_format=shapes_file_format,
                                     inference='rdfs', debug=True,
                                     serialize_report_graph=True)
print(conforms)
print(v_graph)
print(v_text)
# Out:
# ---------------------------------------------------------------------------
# ShapeLoadError                            Traceback (most recent call last)
# <ipython-input-15-f023c60984df> in <module>
#       3                                      shacl_graph_format=shapes_file_format,
#       4                                      inference='rdfs', debug=True,
# ----> 5                                      serialize_report_graph=True)
#       6 print(conforms)
#       7 print(v_graph)
#
# /usr/local/lib/python3.7/site-packages/pyshacl/validate.py in validate(data_graph, shacl_graph, ont_graph, inference, abort_on_error, *args, **kwargs)
#     225             options={'inference': inference, 'abort_on_error': abort_on_error,
#     226                      'logger': log})
# --> 227         conforms, report_graph, report_text = validator.run()
#     228     except ValidationFailure as e:
#     229         conforms = False
#
# /usr/local/lib/python3.7/site-packages/pyshacl/validate.py in run(self)
#     131         reports = []
#     132         non_conformant = False
# --> 133         for s in self.shacl_graph.shapes:
#     134             _is_conform, _reports = s.validate(the_target_graph)
#     135             non_conformant = non_conformant or (not _is_conform)
#
# /usr/local/lib/python3.7/site-packages/pyshacl/shacl_graph.py in shapes(self)
#     114         """
#     115         if len(self._node_shape_cache) < 1:
# --> 116             self._build_node_shape_cache()
#     117         return self._node_shape_cache.values()
#     118
#
# /usr/local/lib/python3.7/site-packages/pyshacl/shacl_graph.py in _build_node_shape_cache(self)
#     193                 raise ShapeLoadError(
#     194                     "A Shape-Expecting & List-Expecting predicate should get a well-formed RDF list with 1 or more members.",
# --> 195                     "https://www.w3.org/TR/shacl/#shapes-recursion")
#     196             for s in list_contents:
#     197                 value_of_shape_expecting.add(s)
#
# ShapeLoadError: A Shape-Expecting & List-Expecting predicate should get a well-formed RDF list with 1 or more members.
# https://www.w3.org/TR/shacl/#shapes-recursion

# %%
import rdflib


g = rdflib.Graph()
g.parse("bioschemas_shacl.json", format="json-ld",publicID = "http://bioschemas.org/specifications/")
# Out:
# <Graph identifier=N27087c401c234625a10c63c277e1f5e5 (<class 'rdflib.graph.Graph'>)>

# %%
import pprint
for stmt in g:
    pprint.pprint(stmt)
# Out:
# (rdflib.term.BNode('Nf61d2116d5684d83bd08b988276a1af1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N0f24aa8de4ef46e3b3273cff3ce9e3a4'))
# (rdflib.term.BNode('N6376130065df4d89b96419b93dd7252e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:maximumAttendeeCapacity'))
# (rdflib.term.BNode('Nc4e0a11224614779a864f32da67ae58b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:eventType'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N18cde36aeeb44cddbe41c119ea957184'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Ne365467fa7004b5ebd7d7ea63bdd7c2e'))
# (rdflib.term.BNode('N81c7237d83e24ec187e55e41948041e4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Date'))
# (rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:citation'))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N830477d5d6c541af84cc51df95e9fdec'))
# (rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N418cdf7a5c554af49aa788bd2881ceeb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N0e66e58b37644c66b16c3a83b002d547'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('URL'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Na39c287a121b408b86709bd7b16ae4e2'))
# (rdflib.term.BNode('N23f5165cf58c439983d80d7f1a9a7b8b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.BNode('N72348722886547eeb85874bdae3994ad'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('Ncd3de18abb054eac966b0f41a5f2f986'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('Nbffd010f9d5c4b8e876f6f465f59276d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:keywords'))
# (rdflib.term.BNode('Nc4e0a11224614779a864f32da67ae58b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N555b3d8fe30b42ae8c2e3c203471e32d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:deadline'))
# (rdflib.term.BNode('N752260e716bf4a969aaa3540641b2dfe'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Na67e364bc06c48aab52dad30b6be7fcc'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Ne4e21f97b3164378adebf694dd627390'))
# (rdflib.term.BNode('N9ae754fd7f7d44bf81489f6025a0d891'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('RegistrationStatus'))
# (rdflib.term.BNode('N8f18395689ec486c9b3306aae76e7a4b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:programme'))
# (rdflib.term.BNode('N5a3700baa10147d9b46559ce3209dbb8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Date'))
# (rdflib.term.BNode('N8ae234403a814c90a3aa5ae1c78885c1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#shapeGraph'),
#  rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'))
# (rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N9064e8ae49b54c929ea495503a313ce6'))
# (rdflib.term.BNode('N18cde36aeeb44cddbe41c119ea957184'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('Nb918b21008e249468b69c40056967586'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:dateModified'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N9ae754fd7f7d44bf81489f6025a0d891'))
# (rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N9064e8ae49b54c929ea495503a313ce6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:datePublished'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N634a5de38a704c90ac69cc635d7f45b7'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:startDate'))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N7a60eb235882415baf91836d0d953fa9'))
# (rdflib.term.BNode('Nc666c28911b340c687ff9faf1b708a32'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Ncbb9a36670204dcc83c1f92fe48c17df'))
# (rdflib.term.BNode('N49259a41ebaa4069aa4f7a3f3f320340'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:dataset'))
# (rdflib.term.BNode('Ne42100b1ede944dabc9b427d7287f7fd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Na4956d5d175e4408a8f04e41caada429'))
# (rdflib.term.BNode('N68f6a5b1eac248838d81836deac93812'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:hostInstitution'))
# (rdflib.term.BNode('N1adc31c1f842449f8878c5d999e35708'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N46c3dc1485be496684b81c1e88a78f3b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'))
# (rdflib.term.BNode('N931e02218d7943308a92e039a9a5f107'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.BNode('Na9ed6d8ac54c48d8bb144ca8fe8df0d1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N49259a41ebaa4069aa4f7a3f3f320340'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Dataset'))
# (rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N409d02c481684a17baab0728af6f4c9d'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N6376130065df4d89b96419b93dd7252e'))
# (rdflib.term.BNode('N5dfd83bb775244cf80ee0f03f8781fcd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N9a87a329998241a3aa805dfd40232af2'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'))
# (rdflib.term.BNode('N35ba054ab40f45b79d89958b42c41ded'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('Nc4e0a11224614779a864f32da67ae58b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('EventType'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N68f6a5b1eac248838d81836deac93812'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Ncd3de18abb054eac966b0f41a5f2f986'))
# (rdflib.term.BNode('Ne447a65be2f4427f880621dedfa31794'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Na4956d5d175e4408a8f04e41caada429'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:socialMedia'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:identifier'))
# (rdflib.term.BNode('Na67e364bc06c48aab52dad30b6be7fcc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N151a895e9d35475eb9a9eee4634a374b'))
# (rdflib.term.BNode('N4f3d7e14ac59431ebcf2118b8c6a10cf'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:subEvent'))
# (rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ne365467fa7004b5ebd7d7ea63bdd7c2e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:DateTime'))
# (rdflib.term.BNode('N11c8ee97bbf24e6eb548efb5882e0d7e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Person'))
# (rdflib.term.BNode('Na88092f1ae1e4f1d90028f55626a5cb8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('N902504577888408791e5332752603519'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:name'))
# (rdflib.term.BNode('Nea228feb64b84d268e43d63cd635ec73'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N1adc31c1f842449f8878c5d999e35708'))
# (rdflib.term.BNode('N7a60eb235882415baf91836d0d953fa9'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N821e5dd40fbd47a4a654d202c47957d5'))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Ne012364aa0c64be29b8904cc3da1d4c5'))
# (rdflib.term.BNode('N1baeae57f22d493abe7f92ec01aceba3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Event'))
# (rdflib.term.BNode('Na39c287a121b408b86709bd7b16ae4e2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Place'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N6b57c5f1d727417d8861cd4995a97573'))
# (rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N4f3d7e14ac59431ebcf2118b8c6a10cf'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Na88092f1ae1e4f1d90028f55626a5cb8'))
# (rdflib.term.BNode('Nb918b21008e249468b69c40056967586'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N418cdf7a5c554af49aa788bd2881ceeb'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N0e66e58b37644c66b16c3a83b002d547'))
# (rdflib.term.BNode('Ne447a65be2f4427f880621dedfa31794'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:topic'))
# (rdflib.term.BNode('Nbd9ccecea74041fbbfd5d3f27b0f9eb2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N1baeae57f22d493abe7f92ec01aceba3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:superEvent'))
# (rdflib.term.BNode('Nd4f2dcb94b864b8a808e96cae1549960'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:CreativeWork'))
# (rdflib.term.BNode('N409d02c481684a17baab0728af6f4c9d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nb4e4a5333b824af2a1c69e0fe63f7707'))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N22e5b02b0b9444509e20c44a7dc75b2e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('N28cadfcf21c6478db955a842c6d262cd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:PropertyValue'))
# (rdflib.term.BNode('N6e93b8a7592e4a29a2fad466bdf2d8bd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Person'))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N28cadfcf21c6478db955a842c6d262cd'))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N43b14ab069fa48bcb07cb4974f466ab4'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ncbb9a36670204dcc83c1f92fe48c17df'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Person'))
# (rdflib.term.BNode('N4282cfd4b50a42b2980f04f1c8b2c5af'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:PostalAddress'))
# (rdflib.term.BNode('N8f18395689ec486c9b3306aae76e7a4b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N4282cfd4b50a42b2980f04f1c8b2c5af'))
# (rdflib.term.BNode('N68f6a5b1eac248838d81836deac93812'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nbfc04a4901bb42e1b80df084102a9548'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N634a5de38a704c90ac69cc635d7f45b7'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('N81c7237d83e24ec187e55e41948041e4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:acceptanceNotificationDate'))
# (rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('URL'))
# (rdflib.term.BNode('N6376130065df4d89b96419b93dd7252e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2754eeed149f49c79e50456edc193862'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N931e02218d7943308a92e039a9a5f107'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Ndc8ad9dec90d4b08860444559f72e88e'))
# (rdflib.term.BNode('N43b14ab069fa48bcb07cb4974f466ab4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Date'))
# (rdflib.term.BNode('Nbd9ccecea74041fbbfd5d3f27b0f9eb2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N0d5d15ec68c649339ac2a7b95812150c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N0d5d15ec68c649339ac2a7b95812150c'))
# (rdflib.term.BNode('N151a895e9d35475eb9a9eee4634a374b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.BNode('N0d5d15ec68c649339ac2a7b95812150c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:sourceOrganization'))
# (rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:name'))
# (rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('URL'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'))
# (rdflib.term.BNode('N0f24aa8de4ef46e3b3273cff3ce9e3a4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N0f10bb22e00348a29de78244fb849a7b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N2754eeed149f49c79e50456edc193862'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N11c8ee97bbf24e6eb548efb5882e0d7e'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#targetClass'),
#  rdflib.term.Literal('bio:Event'))
# (rdflib.term.BNode('N9a87a329998241a3aa805dfd40232af2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:PropertyValue'))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nea228feb64b84d268e43d63cd635ec73'))
# (rdflib.term.BNode('N8ae234403a814c90a3aa5ae1c78885c1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#shapeGraph'),
#  rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'))
# (rdflib.term.BNode('Na9ed6d8ac54c48d8bb144ca8fe8df0d1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:dateModified'))
# (rdflib.term.BNode('N0f10bb22e00348a29de78244fb849a7b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Nbd9ccecea74041fbbfd5d3f27b0f9eb2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('N498bc44e33794c889b247868a5cfbc22'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('Ne012364aa0c64be29b8904cc3da1d4c5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('Ne42100b1ede944dabc9b427d7287f7fd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:url'))
# (rdflib.term.BNode('N8ae234403a814c90a3aa5ae1c78885c1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#shapeGraph'),
#  rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#NodeShape'))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nb13581b18a014e1d84b945bad11cba8b'))
# (rdflib.term.BNode('N3c476c074c7e4580940c13e5daa0529e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:publication'))
# (rdflib.term.BNode('N68f6a5b1eac248838d81836deac93812'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Organization'))
# (rdflib.term.BNode('N6376130065df4d89b96419b93dd7252e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Nbffd010f9d5c4b8e876f6f465f59276d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Nc666c28911b340c687ff9faf1b708a32'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N23f5165cf58c439983d80d7f1a9a7b8b'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N0f10bb22e00348a29de78244fb849a7b'))
# (rdflib.term.BNode('N6376130065df4d89b96419b93dd7252e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Integer'))
# (rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N6e93b8a7592e4a29a2fad466bdf2d8bd'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Na9ed6d8ac54c48d8bb144ca8fe8df0d1'))
# (rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N1212200de2b24626abf9ef6815c83fcd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N3c476c074c7e4580940c13e5daa0529e'))
# (rdflib.term.BNode('N1adc31c1f842449f8878c5d999e35708'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N2c860fd1e3c24bffb16ce3ba00691c56'))
# (rdflib.term.BNode('N0f10bb22e00348a29de78244fb849a7b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#targetClass'),
#  rdflib.term.Literal('bio:DataCatalog'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:identifier'))
# (rdflib.term.BNode('N9ae754fd7f7d44bf81489f6025a0d891'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nc68cdae1024449299f18f63dcfca1a8e'))
# (rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('Nc666c28911b340c687ff9faf1b708a32'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:sponsor'))
# (rdflib.term.BNode('N1ea419ebd7894d08855e64b523fdcf41'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N1adc31c1f842449f8878c5d999e35708'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('N83122aedeea74518b3b4bd7ede3bf170'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('N9ae754fd7f7d44bf81489f6025a0d891'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:registrationStatus'))
# (rdflib.term.BNode('Nea392543648642c790d2193e6c721428'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Organization'))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:identifier'))
# (rdflib.term.BNode('N0d5d15ec68c649339ac2a7b95812150c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Organization'))
# (rdflib.term.BNode('N18635d8200474ef59af7f905b7df4f20'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nbffd010f9d5c4b8e876f6f465f59276d'))
# (rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:endDate'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'))
# (rdflib.term.BNode('N0f10bb22e00348a29de78244fb849a7b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:alternateName'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N498bc44e33794c889b247868a5cfbc22'))
# (rdflib.term.BNode('Ndc8ad9dec90d4b08860444559f72e88e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('Nc4e0a11224614779a864f32da67ae58b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N22e5b02b0b9444509e20c44a7dc75b2e'))
# (rdflib.term.BNode('N0e66e58b37644c66b16c3a83b002d547'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:attachement'))
# (rdflib.term.BNode('N986449247f0c4aa8974faf8987819517'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('N0ab5c7cc528145dcb7304aa9fa9a0dfe'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:provider'))
# (rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N72348722886547eeb85874bdae3994ad'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N902504577888408791e5332752603519'))
# (rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N49259a41ebaa4069aa4f7a3f3f320340'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:fileFormat'))
# (rdflib.term.BNode('Nbffd010f9d5c4b8e876f6f465f59276d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('N8f18395689ec486c9b3306aae76e7a4b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:prerequisite'))
# (rdflib.term.BNode('Na9ed6d8ac54c48d8bb144ca8fe8df0d1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Date'))
# (rdflib.term.BNode('N9064e8ae49b54c929ea495503a313ce6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Date'))
# (rdflib.term.BNode('N2754eeed149f49c79e50456edc193862'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:submitter'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nbd9ccecea74041fbbfd5d3f27b0f9eb2'))
# (rdflib.term.BNode('N7b07d86512354af4ac94d9ee40360d77'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Date'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'))
# (rdflib.term.BNode('N4f3d7e14ac59431ebcf2118b8c6a10cf'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Event'))
# (rdflib.term.BNode('N902504577888408791e5332752603519'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:offers'))
# (rdflib.term.BNode('N9064e8ae49b54c929ea495503a313ce6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'))
# (rdflib.term.BNode('N821e5dd40fbd47a4a654d202c47957d5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#NodeShape'))
# (rdflib.term.BNode('N95f8b3a93bf9490cb01475e7bb3c4f67'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:PropertyValue'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N5a3700baa10147d9b46559ce3209dbb8'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N18635d8200474ef59af7f905b7df4f20'))
# (rdflib.term.BNode('N3c476c074c7e4580940c13e5daa0529e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Na0dc7a88d1404cdeb9c4fba2df4bfcc1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Eligibility'))
# (rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Na0dc7a88d1404cdeb9c4fba2df4bfcc1'))
# (rdflib.term.BNode('N3c476c074c7e4580940c13e5daa0529e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('PublicationEvent'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#targetClass'),
#  rdflib.term.Literal('bio:Dataset'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N1baeae57f22d493abe7f92ec01aceba3'))
# (rdflib.term.BNode('N418cdf7a5c554af49aa788bd2881ceeb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:url'))
# (rdflib.term.BNode('N1baeae57f22d493abe7f92ec01aceba3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Ne4e21f97b3164378adebf694dd627390'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('Nb918b21008e249468b69c40056967586'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:description'))
# (rdflib.term.BNode('N058acd07a49348968c986224e1a721de'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N46c3dc1485be496684b81c1e88a78f3b'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N81c7237d83e24ec187e55e41948041e4'))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:license'))
# (rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N058acd07a49348968c986224e1a721de'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nf2761a9e9a004c31aa31da5e78cf9a1d'))
# (rdflib.term.BNode('Nbd9ccecea74041fbbfd5d3f27b0f9eb2'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:keywords'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N058acd07a49348968c986224e1a721de'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N2754eeed149f49c79e50456edc193862'))
# (rdflib.term.BNode('N0f24aa8de4ef46e3b3273cff3ce9e3a4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:audience'))
# (rdflib.term.BNode('N5cade3ab26ef4081ac72ff4a42b51beb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:string'))
# (rdflib.term.BNode('N5a1a49e6edc84759a213e91373eb96f6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:url'))
# (rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nd4f2dcb94b864b8a808e96cae1549960'))
# (rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N83122aedeea74518b3b4bd7ede3bf170'))
# (rdflib.term.BNode('N695f52de44dd4901b1bda68591f8b3f5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:review'))
# (rdflib.term.BNode('N3238f943c81e4d1d93722d8a5f4f0678'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N017472b148c64a3bb30d8450f14d14e5'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'))
# (rdflib.term.BNode('N902504577888408791e5332752603519'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Offer'))
# (rdflib.term.BNode('N058acd07a49348968c986224e1a721de'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:performer'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nc4e0a11224614779a864f32da67ae58b'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N1212200de2b24626abf9ef6815c83fcd'))
# (rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Ncd3de18abb054eac966b0f41a5f2f986'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nc37452ce9efb4622ba31b0ab1e990886'))
# (rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nbfc04a4901bb42e1b80df084102a9548'))
# (rdflib.term.BNode('N2aad4c642c744d08b3d5ba47b59879e8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N6d091e16deae4fd789eb2d8c40e78027'))
# (rdflib.term.BNode('N8edcc0d306ae45f4b0445654525e0ae6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N5dfd83bb775244cf80ee0f03f8781fcd'))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nccaa9aabd68e411d8b69f0842ee21934'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nb918b21008e249468b69c40056967586'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N752260e716bf4a969aaa3540641b2dfe'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N2918d8f2bb6c4969854176fcbf326ac3'))
# (rdflib.term.BNode('Nb918b21008e249468b69c40056967586'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DatasetShape'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#NodeShape'))
# (rdflib.term.BNode('Nb4e4a5333b824af2a1c69e0fe63f7707'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N830477d5d6c541af84cc51df95e9fdec'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'))
# (rdflib.term.BNode('N2918d8f2bb6c4969854176fcbf326ac3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nf61d2116d5684d83bd08b988276a1af1'))
# (rdflib.term.BNode('Nc37452ce9efb4622ba31b0ab1e990886'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nea392543648642c790d2193e6c721428'))
# (rdflib.term.BNode('Nccaa9aabd68e411d8b69f0842ee21934'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N418cdf7a5c554af49aa788bd2881ceeb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('URL'))
# (rdflib.term.BNode('Nf8bb7c9fb01947aa976d27cb1236cc38'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Text'))
# (rdflib.term.BNode('Ncd3de18abb054eac966b0f41a5f2f986'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N8f18395689ec486c9b3306aae76e7a4b'))
# (rdflib.term.BNode('N1adc31c1f842449f8878c5d999e35708'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:description'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nffe0b6b57c5f494ba249bbba75eb6fec'))
# (rdflib.term.BNode('Ncf9ba4644deb4cfc8aa75761b540e1d0'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('Nf8bb7c9fb01947aa976d27cb1236cc38'))
# (rdflib.term.BNode('N6b57c5f1d727417d8861cd4995a97573'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('Na4956d5d175e4408a8f04e41caada429'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('URL'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N695f52de44dd4901b1bda68591f8b3f5'))
# (rdflib.term.BNode('N70bb0552afbc4d1eac363cda8d7dfebb'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#maxCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N2af0f6e40148441a8fe64d1e251107e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N35ba054ab40f45b79d89958b42c41ded'))
# (rdflib.term.BNode('Nf321bb8a2cde43e9aef37948bfd1370c'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:description'))
# (rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N555b3d8fe30b42ae8c2e3c203471e32d'))
# (rdflib.term.BNode('Na325a2ade8a8473ead9b5ff4fcd3f714'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('Nb13581b18a014e1d84b945bad11cba8b'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:URL'))
# (rdflib.term.BNode('N6d091e16deae4fd789eb2d8c40e78027'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:DateTime'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'))
# (rdflib.term.BNode('N25d994c9dfd64640a9d492524c0d81b4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:accreditation'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Ne42100b1ede944dabc9b427d7287f7fd'))
# (rdflib.term.BNode('N2c860fd1e3c24bffb16ce3ba00691c56'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#datatype'),
#  rdflib.term.Literal('xsd:anyURL'))
# (rdflib.term.BNode('N2fb284e0419d4c0db8dcd27027295adc'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N1f77db8fffbb464f9a7283f0e080c4f5'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Nc666c28911b340c687ff9faf1b708a32'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('Nd0525804ada743afbaa49226f65cbaa8'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N986449247f0c4aa8974faf8987819517'))
# (rdflib.term.BNode('Ncd3de18abb054eac966b0f41a5f2f986'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:keywords'))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N5cade3ab26ef4081ac72ff4a42b51beb'))
# (rdflib.term.BNode('N0898566466c142edb4e9b1b7011d19db'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N1ea419ebd7894d08855e64b523fdcf41'))
# (rdflib.term.BNode('N9a9b564893f342da9f7d539dc74a6721'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N7b07d86512354af4ac94d9ee40360d77'))
# (rdflib.term.BNode('Ne42100b1ede944dabc9b427d7287f7fd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:name'))
# (rdflib.term.BNode('N2a8678c6f2d642c19b42bd9e0dbdd23d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Warning'))
# (rdflib.term.BNode('Nb918b21008e249468b69c40056967586'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('Ne42100b1ede944dabc9b427d7287f7fd'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#minCount'),
#  rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.BNode('N017472b148c64a3bb30d8450f14d14e5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:CreativeWork'))
# (rdflib.term.BNode('Ne447a65be2f4427f880621dedfa31794'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Topic'))
# (rdflib.term.BNode('N0f24aa8de4ef46e3b3273cff3ce9e3a4'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Audience'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/DataCatalogShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('N49259a41ebaa4069aa4f7a3f3f320340'))
# (rdflib.term.BNode('Nf61d2116d5684d83bd08b988276a1af1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Text'))
# (rdflib.term.BNode('Nf61d2116d5684d83bd08b988276a1af1'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:alternateName'))
# (rdflib.term.BNode('Nf2761a9e9a004c31aa31da5e78cf9a1d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Person'))
# (rdflib.term.URIRef('http://bioschemas.org/specifications/EventShape'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#property'),
#  rdflib.term.BNode('Ne447a65be2f4427f880621dedfa31794'))
# (rdflib.term.BNode('N975c85f6749349959a7cbd01cd98685d'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:location'))
# (rdflib.term.BNode('N695f52de44dd4901b1bda68591f8b3f5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('Review'))
# (rdflib.term.BNode('N68f6a5b1eac248838d81836deac93812'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#severity'),
#  rdflib.term.Literal('sh:Violation'))
# (rdflib.term.BNode('N551f3360fdbd4e6c859aaf120f959f03'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N95f8b3a93bf9490cb01475e7bb3c4f67'))
# (rdflib.term.BNode('Nc68cdae1024449299f18f63dcfca1a8e'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:DateTime'))
# (rdflib.term.BNode('N1f9f3ad571214d8b9a64a37998db9ca3'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#or'),
#  rdflib.term.BNode('N0ab5c7cc528145dcb7304aa9fa9a0dfe'))
# (rdflib.term.BNode('Ne1102edf35014d0587d4482feee30cb6'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:eligibility'))
# (rdflib.term.BNode('Nc3e6ec2409fd4c70ad23ff4659310c96'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#path'),
#  rdflib.term.Literal('schema:organizer'))
# (rdflib.term.BNode('N1f77db8fffbb464f9a7283f0e080c4f5'),
#  rdflib.term.URIRef('http://www.w3.org/ns/shacl#class'),
#  rdflib.term.Literal('schema:Person'))

# %%
g.serialize(destination='shacl.ttl', format='turtle')

# %%
import yaml
import requests
import json
import rdflib

def read_in_spec(type):

    if not isinstance(type,str):
        return("Type must be a string.")

    url = 'https://raw.githubusercontent.com/BioSchemas/specifications/master/'+type+'/specification.html'

    req = requests.get(url)
    print(type)
    document = req.content.decode().split('/n')[-1]

    document = document[:document.rfind('\n')]

    specs = yaml.load(document)

    return(specs)


specs = []
types = ['DataCatalog','Dataset','Event','Sample',\
         'Taxon','TrainingMaterial']

for type in types:

    spec = read_in_spec(type)
    specs.append(spec)

shacl_rules = {
    "@context": {
        "rdf":  "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
        "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
        "sh":   "http://www.w3.org/ns/shacl#",
        "xsd":  "http://www.w3.org/2001/XMLSchema#",
        "schema": "http://schema.org/",
        "bio":"http://bioschemas.org/specifications/"
    },
    "sh:shapeGraph":[]
  }

for i in range(len(specs)):

    spec = specs[i]
    type = types[i]

    specGraph = {
        '@id':type + "Shape",
        "@type":"sh:NodeShape",
        "sh:targetClass":"bio:"+type,
        "sh:property":[]
    }

    if not spec.get('properties'):
        continue

    for property in spec.get('properties'):

        prop_dict = {
            "sh:path":"schema:"+property.get('name')
        }

        severity = property.get('marginality')

        if severity == 'Minimum':
            prop_dict['sh:severity'] = 'sh:Violation'
            prop_dict['sh:minCount'] = 1

        elif severity == 'Recommended':
            prop_dict['sh:severity'] = 'sh:Warning'

        cardinality = property.get('cardinality')

        if cardinality == 'ONE':
            prop_dict['sh:maxCount'] = 1

        expected_types = property.get('expected_type')

        if len(expected_types) > 1:

            prop_dict['sh:or'] = []

            for allowed in expected_types:

                prop_dict['sh:or'].append({'sh:class':'schema:' + allowed})

                if allowed == 'Text':
                    prop_dict['sh:or'].append({"sh:datatype": "xsd:string"})

                elif allowed == 'URL':
                    prop_dict['sh:or'].append({"sh:datatype": "xsd:anyURL"})
        else:
            prop_dict['sh:class'] = expected_types[0]

        specGraph['sh:property'].append(prop_dict)

    shacl_rules['sh:shapeGraph'].append(specGraph)


g = rdflib.Graph()
g.parse(json.dumps(shacl_rules), format="json-ld",publicID = "http://bioschemas.org/specifications/")
# Out:
# DataCatalog
# Dataset
# Event
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:19: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# file:///Users/justinniestroy-admin/Documents/Work/bioschemas-shacl-generator/{"@context": {"rdf": "http:/www.w3.org/1999/02/22-rdf-syntax-ns#", "rdfs": "http://www.w3.org/2000/01/rdf-schema#", "sh": "http://www.w3.org/ns/shacl#", "xsd": "http://www.w3.org/2001/XMLSchema#", "schema": "http://schema.org/", "bio": "http://bioschemas.org/specifications/"}, "sh:shapeGraph": [{"@id": "DataCatalogShape", "@type": "sh:NodeShape", "sh:targetClass": "bio:DataCatalog", "sh:property": [{"sh:path": "schema:dataset", "sh:severity": "sh:Warning", "sh:class": "Dataset"}, {"sh:path": "schema:citation", "sh:severity": "sh:Warning", "sh:or": [{"sh:class": "schema:CreativeWork"}, {"sh:class": "schema:Text"}, {"sh:datatype": "xsd:string"}]}, {"sh:path": "schema:dateModified", "sh:severity": "sh:Warning", "sh:maxCount": 1, "sh:or": [{"sh:class": "schema:Date"}, {"sh:class": "schema:DateTime"}]}, {"sh:path": "schema:datePublished", "sh:maxCount": 1, "sh:class": "Date"}, {"sh:path": "schema:fileFormat", "sh:or": [{"sh:class": "schema:Text"}, {"sh:datatype": "xsd:string"}, {"sh:class": "schema:URL"}, {"sh:datatype": "xsd:anyURL"}]}, {"sh:path": "schema:keywords", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:class": "Text"}, {"sh:path": "schema:license", "sh:severity": "sh:Warning", "sh:maxCount": 1, "sh:or": [{"sh:class": "schema:CreativeWork"}, {"sh:class": "schema:URL"}, {"sh:datatype": "xsd:anyURL"}]}, {"sh:path": "schema:provider", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:or": [{"sh:class": "schema:Organization"}, {"sh:class": "schema:Person"}]}, {"sh:path": "schema:publication", "sh:severity": "sh:Warning", "sh:class": "PublicationEvent"}, {"sh:path": "schema:sourceOrganization", "sh:severity": "sh:Warning", "sh:class": "Organization"}, {"sh:path": "schema:alternateName", "sh:severity": "sh:Warning", "sh:class": "Text"}, {"sh:path": "schema:description", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "Text"}, {"sh:path": "schema:identifier", "sh:severity": "sh:Warning", "sh:or": [{"sh:class": "schema:PropertyValue"}, {"sh:class": "schema:Text"}, {"sh:datatype": "xsd:string"}, {"sh:class": "schema:URL"}, {"sh:datatype": "xsd:anyURL"}]}, {"sh:path": "schema:name", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "Text"}, {"sh:path": "schema:url", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "URL"}]}, {"@id": "DatasetShape", "@type": "sh:NodeShape", "sh:targetClass": "bio:Dataset", "sh:property": [{"sh:path": "schema:name", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "Text"}, {"sh:path": "schema:description", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "Text"}, {"sh:path": "schema:url", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:class": "URL"}, {"sh:path": "schema:identifier", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:or": [{"sh:class": "schema:PropertyValue"}, {"sh:class": "schema:Text"}, {"sh:datatype": "xsd:string"}, {"sh:class": "schema:URL"}, {"sh:datatype": "xsd:anyURL"}]}, {"sh:path": "schema:keywords", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:class": "Text"}]}, {"@id": "EventShape", "@type": "sh:NodeShape", "sh:targetClass": "bio:Event", "sh:property": [{"sh:path": "schema:audience", "sh:severity": "sh:Warning", "sh:class": "Audience"}, {"sh:path": "schema:endDate", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:or": [{"sh:class": "schema:Date"}, {"sh:class": "schema:DateTime"}]}, {"sh:path": "schema:location", "sh:severity": "sh:Violation", "sh:minCount": 1, "sh:maxCount": 1, "sh:or": [{"sh:class": "schema:Place"}, {"sh:class": "schema:PostalAddress"}, {"sh:class": "schema:Text"}, {"sh:datatype": "xsd:string"}]}, {"sh:path": "schema:maximumAttendeeCapacity", "sh:severity": "sh:Warning", "sh:maxCount": 1, "sh:class": "Integer"}, {"sh:path": "schema:offers", "sh:maxCou ...
# file:///Users/justinniestroy-admin/Documents/Work/bioschemas-shacl-generator/{"@context": {"rdf": "http:/www.w3.org/1999/02/22-rdf-syntax-ns does not look like a valid URI, trying to serialize this will break.
# Sample
# Taxon
# TrainingMaterial
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d489e47f56d2> in <module>
#     102
#     103 g = rdflib.Graph()
# --> 104 g.parse(json.dumps(shacl_rules), format="json-ld",publicID = "http://bioschemas.org/specifications/")
#
# /usr/local/lib/python3.7/site-packages/rdflib/graph.py in parse(self, source, publicID, format, location, file, data, **args)
#    1032         source = create_input_source(source=source, publicID=publicID,
#    1033                                      location=location, file=file,
# -> 1034                                      data=data, format=format)
#    1035         if format is None:
#    1036             format = source.content_type
#
# /usr/local/lib/python3.7/site-packages/rdflib/parser.py in create_input_source(source, publicID, location, file, data, format)
#     182         if absolute_location.startswith("file:///"):
#     183             filename = url2pathname(absolute_location.replace("file:///", "/"))
# --> 184             file = open(filename, "rb")
#     185         else:
#     186             input_source = URLInputSource(absolute_location, format)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/justinniestroy-admin/Documents/Work/bioschemas-shacl-generator/{"@context": {"rdf": "http:/www.w3.org/1999/02/22-rdf-syntax-ns'
